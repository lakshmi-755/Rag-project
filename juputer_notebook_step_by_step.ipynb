# %%
import openai
import sys
from dotenv import load_dotenv 
load_dotenv()
import os
api_key = os.getenv("OPENAI_API_KEY")

# %%
from langchain_community.document_loaders import PyPDFLoader

# %%
loader=PyPDFLoader("C:/Users/HP/OneDrive/Desktop/ragproject/knowledge_base.pdf")

# %%
pages=loader.load()
